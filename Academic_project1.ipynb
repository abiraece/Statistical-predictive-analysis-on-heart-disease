# %% [markdown]
# #                                                MINIPROJECT

# %% [markdown]
# This data set dates from 1988 and consists of four databases: Cleveland, Hungary, Switzerland, and Long Beach V. It contains 76 attributes, including the predicted attribute, but all published experiments refer to using a subset of 14 of them. The "target" field refers to the presence of heart disease in the patient. It is integer valued 0 = no disease and 1 = disease.

# %% [markdown]
# ### About the dataset (Heart Disease Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the heart disease in a person. <br> Attribute information:
#
# **age:** Age various from young to old
#
# **sex:** Gender with 0 and 1
#
# **cp:** chest pain type (4 values)
#
# **restbps:** resting blood pressure
#
# **chol:** serum cholestoral in mg/dl
#
# **fbs:** fasting blood sugar > 120 mg/dl
#
# **restecg:** resting electrocardiographic results (values 0,1,2)
#
# **maxheart:** maximum heart rate achieved
#
# **exang:** exercise induced angina
#
# **oldpeak:** oldpeak = ST depression induced by exercise relative to rest
#
# **slope:** the slope of the peak exercise ST segment
#
# **ca:** number of major vessels (0-3) colored by flourosopy
#
# **thal:** thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
#
# **target:** 0 = no Disease; 1 = Disease
#
# The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.

# %% [markdown]
# # Data Pre-Processing:

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#03b7b4;"> 1. Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#03b7b4;"> 2. Read the Dataset

# %%
d = pd.read_csv('heart.csv')
d.head() # head() will give first 5 rows in the dataset
# Out:
#    age  sex  cp  restbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0      125   212    0        1      168      0      1.0      2
# 1   53    1   0      140   203    1        0      155      1      3.1      0
# 2   70    1   0      145   174    0        1      125      1      2.6      0
# 3   61    1   0      148   203    0        1      161      0      0.0      2
# 4   62    0   0      138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#03b7b4;"> 3. Check the shape of Dataset

# %%
print('Heart Disease Dataset samples are:',d.shape) # number of rows and attributes/columns in the dataset
# Out:
# Heart Disease Dataset samples are: (1025, 14)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#02b5b5;"> 4. Numerical Features of Data

# %%
d.info() # gives about the datatype of individual attributes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      1025 non-null   int64
#  1   sex      1025 non-null   int64
#  2   cp       1025 non-null   int64
#  3   restbps  1025 non-null   int64
#  4   chol     1025 non-null   int64
#  5   fbs      1025 non-null   int64
#  6   restecg  1025 non-null   int64
#  7   thalach  1025 non-null   int64
#  8   exang    1025 non-null   int64
#  9   oldpeak  1025 non-null   float64
#  10  slope    1025 non-null   int64
#  11  ca       1025 non-null   int64
#  12  thal     1025 non-null   int64
#  13  target   1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#03b7b4;"> 5. Check for Null Value

# %%
d.isnull().sum() # gives the null values present in the individual column of dataset
# Out:
# age        0
# sex        0
# cp         0
# restbps    0
# chol       0
# fbs        0
# restecg    0
# thalach    0
# exang      0
# oldpeak    0
# slope      0
# ca         0
# thal       0
# target     0
# dtype: int64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#03b7b4;"> 6. Statistical Characteristic of Data

# %%
print('Statistical Characteristic of Data:')
d.describe() # gives statistical characteristic about entire dataset
# Out:
# Statistical Characteristic of Data:
#                age          sex           cp      restbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#03b7b4;"> 7. Check the correlation for the given Dataset

# %%
d.corr()
# Out:
#               age       sex        cp   restbps      chol       fbs   restecg  \
# age      1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243 -0.132696
# sex     -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200 -0.055117
# cp      -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294  0.043581
# restbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767 -0.123794
# chol     0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917 -0.147410
# fbs      0.121243  0.027200  0.079294  0.181767  0.026917  1.000000 -0.104051
# restecg -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051  1.000000
# thalach -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866  0.048411
# exang    0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261 -0.065606
# oldpeak  0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859 -0.050114
# slope   -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902  0.086086
# ...

# %%
output feature is considered as "Target", all other attributes are considered as input features.
From the above correlation table we can conclude that Target variable depend on all given input features.

# %%
sns.pairplot(d)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(d.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From Statistical approach:

# %%
import scipy.stats as stats
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu,shapiro,wilcoxon,ttest_rel
from statsmodels.stats.power import ttest_power
from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import chisquare
from scipy.stats import  chi2_contingency

# %% [markdown]
# 1 . Average Rate of Heart beat is greater than 70 for healthier person.

# %%
c1 = np.array(d[d['target']==0]['thalach'])

# %%
# Hypothesis:
H0 : Healthy Person average heart rate > 70
Ha : Healthy Person average heart rate <= 70

# %%
# To check for normality:
print('Output of Normality for Maximum heart rate is:',shapiro(c1))

# Pvalue < 0.05. Data is not normal. For one sample skewed data, "wilcoxon test will be performed"
# Out:
# Output of Normality for Maximum heart rate is: ShapiroResult(statistic=0.9878486394882202, pvalue=0.0003625799436122179)

# %%
# one sample test:
print('Output of one sample two tail test is:',wilcoxon(c1-c1.mean()))

#Inference:
# pvalue > 0.05. Null Hypothesis hold good. Therefore Healthy person average heart rate > 70.
# Out:
# Output of one sample two tail test is: WilcoxonResult(statistic=61111.0, pvalue=0.6948746726546262)

# %%
# posthoc analysis:
print('Average Heart rate for healthier person as per the given data is:',c1.mean())
# Out:
# Average Heart rate for healthier person as per the given data is: 139.1302605210421

# %% [markdown]
# 2.Does Age has effect on Heart Disease

# %%
# Hypothesis:
H0 : Age has no effect on Heart Disease
Ha : Age has effect on Heart Disease

# %%
d['age_group'] = pd.cut(x=d['age'],bins=[0,19,35,55,90],labels=['Teenagers','Young','Middle','Old Age People'])
d.head()
# Out:
#    age  sex  cp  restbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0      125   212    0        1      168      0      1.0      2
# 1   53    1   0      140   203    1        0      155      1      3.1      0
# 2   70    1   0      145   174    0        1      125      1      2.6      0
# 3   61    1   0      148   203    0        1      161      0      0.0      2
# 4   62    0   0      138   294    1        1      106      0      1.9      1
#
#    ca  thal  target       age_group
# 0   2     3       0          Middle
# 1   0     3       0          Middle
# 2   0     3       0  Old Age People
# 3   1     3       0  Old Age People
# 4   3     2       0  Old Age People

# %%
# Graphical approach:

# %%
df = d[d['target']==1][['age','age_group','target']]
df1 = d[d['target']==0][['age','age_group','target']]

# %%
sns.violinplot(x='age_group',y='target',data=d)
plt.show()

# %%
# Statistical approach:

# %%
d1 = pd.crosstab(d['target'],d['age_group'])
d1
# Out:
# age_group  Young  Middle  Old Age People
# target
# 0              7     171             321
# 1             18     310             198

# %%
chi2_contingency(d1)
# Out:
# (73.49846725308345,
#  1.0965050137436768e-16,
#  2,
#  array([[ 12.17073171, 234.16487805, 252.66439024],
#         [ 12.82926829, 246.83512195, 266.33560976]]))

# %%
# Inference:
Pvalue for age_group < 0.05. Therefore Ha holds good.

From the below posthoc analysis, Proportion of diseased young age people are 72% which is maximum and 
Proportion of helathy young age people are 28% which is minimum.

Therefore we can conclude that, Age_group has effect on Heart Disease

# %%
# posthoc analysis:
pyd = 18 / (7+18)
pmd = 310 / (171+310)
pod = 198 / (321+198)

pyh = 7 / (7+18)
pmh = 171 / (171+310)
poh = 321 / (321+198)

(pyd,pmd,pod),(pyh,pmh,poh)
# Out:
# ((0.72, 0.6444906444906445, 0.3815028901734104),
#  (0.28, 0.35550935550935553, 0.6184971098265896))

# %% [markdown]
# 3 . People who's average Age above 45 affected by Cardiac Problem

# %%
# Hypothesis:
H0 : Person with mean age > 45 has cardiac problem
Ha : Person with mean age <= 45 has cardiac problem

# %%
age = np.array(d[d['target']==1]['age'])
age
# Out:
# array([58, 71, 34, 34, 51, 50, 58, 67, 45, 63, 42, 44, 50, 50, 51, 59, 64,
#        65, 54, 55, 42, 41, 66, 58, 38, 56, 48, 29, 66, 59, 29, 53, 37, 47,
#        48, 52, 52, 38, 37, 44, 58, 54, 62, 62, 45, 57, 76, 43, 57, 54, 47,
#        52, 53, 29, 42, 54, 65, 60, 66, 53, 52, 57, 60, 51, 41, 50, 54, 55,
#        64, 47, 41, 34, 47, 51, 52, 39, 54, 54, 40, 54, 67, 41, 51, 57, 43,
#        45, 43, 56, 39, 64, 42, 45, 41, 56, 67, 69, 59, 45, 60, 62, 34, 52,
#        64, 66, 42, 41, 38, 42, 43, 45, 49, 41, 64, 39, 51, 54, 44, 52, 56,
#        41, 49, 64, 54, 38, 51, 44, 39, 42, 45, 62, 35, 64, 66, 44, 54, 48,
#        55, 45, 71, 43, 44, 39, 66, 57, 44, 41, 45, 35, 41, 64, 71, 64, 71,
#        58, 52, 61, 59, 35, 52, 46, 51, 55, 52, 44, 44, 56, 74, 40, 42, 64,
#        63, 53, 53, 48, 48, 56, 53, 37, 37, 54, 57, 54, 38, 44, 65, 52, 41,
#        54, 66, 57, 46, 53, 48, 62, 43, 53, 53, 58, 51, 54, 46, 66, 59, 64,
# ...

# %%
# Test for Normality:
shapiro(age)

# Pvalue < 0.05. Therefore performing one sample wilcoxon test
# Out:
# ShapiroResult(statistic=0.9862686991691589, pvalue=7.327955245273188e-05)

# %%
# mean test:
wilcoxon(age - age.mean())
# Out:
# WilcoxonResult(statistic=68390.0, pvalue=0.7939953040945469)

# %%
# inference:
Pvalue < 0.05. H0 holds good. Therefore person with mean age > 45 has cardiac problem

# %%
# Posthoc analysis:
age.mean()

# From the below average value we can conclude that, mean age of person who is suffering with cardiac problem is 52 for the given data.
# Out:
# 52.40874524714829

# %% [markdown]
# 4. Does Blood Pressure has effect on Target?

# %%
# Hypothesis:
H0 : Blood Pressure has no effect on target
Ha : Blood Pressure has effect on Target

# %%
g1 = np.array(d[d['target']==0]['restbps'])
g2 = np.array(d[d['target']==1]['restbps'])

# %%
# Test of normality:
print('Output of normality test for no disease is:',shapiro(g1))
print('Output of normality test for diseased person is:',shapiro(g2))

# for both groups pvalue < 0.05. Therefore preceding with manmannwhitneyu test
# Out:
# Output of normality test for no disease is: ShapiroResult(statistic=0.9466421604156494, pvalue=2.0134044171477017e-12)
# Output of normality test for diseased person is: ShapiroResult(statistic=0.977814793586731, pvalue=3.6595537267203326e-07)

# %%
# mean test:
mannwhitneyu(g1,g2)
# Out:
# MannwhitneyuResult(statistic=113851.0, pvalue=0.00011652858189112656)

# %%
# Inference: 
Pvalue < 0.05. Ha holds good.

# %%
# posthoc analysis:
print('Average Blood pressure for healthy person is:',g1.mean())
print('Average blood pressure for diseased person is:',g2.mean())

# From the below mean value we can conclude that mean difference between healthy and diseased person is approximately 4.86.
# Therefore we can conclude that Blood Pressure has effect on Target.
# Out:
# Average Blood pressure for healthy person is: 134.1062124248497
# Average blood pressure for diseased person is: 129.24524714828897

# %% [markdown]
# 5. Does Gender has effect on serum Cholestral?

# %%
# Hypothesis:
H0 : Gender has no effect on serum cholestral
Ha : Gender has effect on serum cholestral

# %%
sns.violinplot(x='sex',y='chol',data=d)
plt.show()

# %%
# assumption:
In the given dataset, sex column is given as 0 and 1. Here we are assuming 0 as Male and 1 as Female and doing further analysis.
# Out:
# Index(['age', 'sex', 'cp', 'restbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target', 'age_group'],
#       dtype='object')

# %%
g1 = np.array(d[d['sex']==0]['chol']) # consider as male cholestral level
g2 = np.array(d[d['sex']==1]['chol']) # consider as female cholestral level

# %%
# Test for normality:
print('Normality test output for male candidates with cholestral levels are:',shapiro(g1))
print('Normality test output for female candidates with cholestral levels are:',shapiro(g2))

# For both the groups pvalue<0.05. Therefore data is skewed. Proceeding with mannwhitneyu test
# Out:
# Normality test output for male candidates with cholestral levels are: ShapiroResult(statistic=0.9254664182662964, pvalue=2.2823598913590537e-11)
# Normality test output for female candidates with cholestral levels are: ShapiroResult(statistic=0.9916911721229553, pvalue=0.0004952535382471979)

# %%
# mean Test:
mannwhitneyu(g1,g2)
# Out:
# MannwhitneyuResult(statistic=89877.0, pvalue=4.895315339229471e-07)

# %%
# posthoc analysis:
print('Mean Cholestral level for male:',g1.mean())
print('Mean Cholestral level for female:',g2.mean())

# Conclusion: Average Cholestral level for male is higher than Average cholestral level of Female
# Out:
# Mean Cholestral level for male: 261.45512820512823
# Mean Cholestral level for female: 239.23702664796633

# %% [markdown]
# 6. Serum Cholestral has effect on Target Disease?

# %%
# hypothesis:
H0 : Cholestral has no effect on heart disease
Ha : Cholestral has effect on heart disease

# %%
g1 = np.array(d[d['target']==0]['chol'])
g2 = np.array(d[d['target']==1]['chol'])

# %%
# Test for normality:
print(shapiro(g1))
print(shapiro(g2))
# Out:
# ShapiroResult(statistic=0.9875831604003906, pvalue=0.0002997656411025673)
# ShapiroResult(statistic=0.8978157639503479, pvalue=2.9994485113701186e-18)

# %%
# Mean Test:
mannwhitneyu(g1,g2)
# Out:
# MannwhitneyuResult(statistic=111087.5, pvalue=1.0521988368166756e-05)

# %%
# Posthoc analysis:
print('Average cholestral value for healthy person is:',g1.mean())
print('Average cholestral value for diseased person is:',g2.mean())

# inference:
# The mean difference of cholestral value between healthy and diseased person is approximatley 10.31.
# Therefore we can conclude that cholestral has effect on target.
# Out:
# Average cholestral value for healthy person is: 251.2925851703407
# Average cholestral value for diseased person is: 240.97908745247148

# %% [markdown]
# 7.Does Serum Cholestoral has an effect on high blood pressure?

# %%
# Graphical analysis:
sns.regplot(d['chol'],d['restbps'])
plt.show()

# %%
# Hypothesis:
H0 : Serum Cholestral has no effect on High Blood Pressure
Ha : Serum Cholestral has effect on high Blood Pressure

# %%
g1 = d['chol']
g2 = d['restbps']

# %%
# Test for normality:
print('Normality test output for serum cholestral is:',shapiro(g1))
print('Normality test output for Blood pressure is:',shapiro(g2))

# Pvalues < 0.05. So the Data is skewed. Proceeding with mannwhitneyu
# Out:
# Normality test output for serum cholestral is: ShapiroResult(statistic=0.9502224922180176, pvalue=3.998895483546755e-18)
# Normality test output for Blood pressure is: ShapiroResult(statistic=0.9633121490478516, pvalue=2.194891912264598e-15)

# %%
# Mean test:
mannwhitneyu(g1,g2)
# Out:
# MannwhitneyuResult(statistic=7989.0, pvalue=0.0)

# %%
246 - 131.61170731707318
# Out:
# 114.38829268292682

# %%
# posthoc analysis:

print('Average mean of cholestral is:',g1.mean())
print('Average mean of Blood Pressure is:',g2.mean())

# From the below values the mean difference between cholestral and blood pressure is approximately 114.38.
#  Therefore we can conclude that Serum cholestral has an effect in blood pressure.
# Out:
# Average mean of cholestral is: 246.0
# Average mean of Blood Pressure is: 131.61170731707318

# %% [markdown]
# 8. Does Fasting sugar level has an effect on high blood pressure?

# %%
# Grphical analysis:
sns.boxplot(d['fbs'],d['restbps'])
plt.show()
# Out:
# C:\Users\ELCOT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Hypothesis:
H0 : Fasting Blood sugar has no effect on High Blood Pressure
Ha : Fasting Blood sugar has effect on High Blood Pressure

# %%
# Assumption:
Fasting Blood Pressure above 120 mg/dl are considered as '1' and Fastin Blood Pressure below 120 mg/dl are considered as '0'

# %%
d['fbs'].value_counts()
# Out:
# 0    872
# 1    153
# Name: fbs, dtype: int64

# %%
g1 = d[d['fbs']==1]['restbps']
g2 = d[d['fbs']==0]['restbps']

# %%
# Test for normality:
print('Normality test output for Blood pressure with Blood sugar is:',shapiro(g1))
print('Normality test output for Blood pressure without Blood sugar is:',shapiro(g2))

# pvalue < 0.05. Data is skewed. Proceeding with mannwhitneyu test
# Out:
# Normality test output for Blood pressure with Blood sugar is: ShapiroResult(statistic=0.9220036864280701, pvalue=2.281547466509437e-07)
# Normality test output for Blood pressure without Blood sugar is: ShapiroResult(statistic=0.9720150232315063, pvalue=6.8019353170745145e-12)

# %%
# Mean test:
mannwhitneyu(g1,g2)
# Out:
# MannwhitneyuResult(statistic=50296.5, pvalue=5.507916238959195e-07)

# %%
# posthoc analysis:
print('Mean value of Blood Pressure with blood sugar is:',g1.mean())
print('Mean value of Blood Pressure without blood sugar is:',g2.mean())

# inference:
From the mannwhitneyu test we can infer that Pvalue <0.05. Null hypothesis is rejected.
There is a mean difference between Blood Pressure with Blood sugar and Blood Pressure without Blood sugar. Therefore 
Blood Pressure has effect on Blood Sugar.
# Out:
# Mean value of Blood Pressure with blood sugar is: 139.20915032679738
# Mean value of Blood Pressure without blood sugar is: 130.27866972477065

# %% [markdown]
# 9. Does Cholestoral has effect on Age?

# %%
# Hypothesis:
H0 : Cholestoral has no effect on age
Ha : Cholestoral has effect on age

# %%
g1 = d['chol']
g2 = d['age']

# %%
# Test for normality:
print('Output of normality for cholestoral is:',shapiro(g1))
print('Output of normality for age is:',shapiro(g2))

# Pvalue < 0.05 for both g1 and g2. Data is skewed.
# Out:
# Output of normality for cholestoral is: ShapiroResult(statistic=0.9502224922180176, pvalue=3.998895483546755e-18)
# Output of normality for age is: ShapiroResult(statistic=0.9843646287918091, pvalue=5.051827400848197e-09)

# %%
# mean test:
mannwhitneyu(g1,g2)
# Out:
# MannwhitneyuResult(statistic=0.0, pvalue=0.0)

# %%
# posthoc analysis:
print('Mean of cholestoral for the given dataset is:',g1.mean())
print('Mean of Age for the given dataset is:',g2.mean())
# Out:
# Mean of cholestoral for the given dataset is: 246.0
# Mean of Age for the given dataset is: 54.43414634146342

# %%
sns.regplot(x='chol',y='age',data=d)
plt.show()

# %%
# Inference:

Pvalue < 0.05. Null hypothesis is rejected.
Therefore cholestoral has effect on age.

# %% [markdown]
# 10. Does exercise induce angina has effect on blood pressure?

# %%
# Hypothesis:
H0 : Exercise induce angina has no effect on blood pressure
Ha : Exercise induce angina has effect on blood pressure

# %%
g1 = d[d['exang']==0]['restbps']
g2 = d[d['exang']==1]['restbps']

# %%
# test for normality:
print('Output of normality for blood pressure without exercise induce angina is:',shapiro(g1))
print('Output of normality for blood pressure without exercise induce angina is:',shapiro(g2))

#Pvalue < 0.05. Data is skewed. so proceeding with mannwhitneyu test
# Out:
# Output of normality for blood pressure without exercise induce angina is: ShapiroResult(statistic=0.9752237200737, pvalue=2.5485924481927213e-09)
# Output of normality for blood pressure without exercise induce angina is: ShapiroResult(statistic=0.9418547749519348, pvalue=2.1796094096249163e-10)

# %%
# mean test:
mannwhitneyu(g1,g2)
# Out:
# MannwhitneyuResult(statistic=111041.5, pvalue=0.08057809048550241)

# %%
# Inference:
Pvalue > 0.05. Null hypothesis is accepeted. Exercise induce angina has no effect on blood pressure

# %% [markdown]
# 11. Number of major vessel colored by flourosopy has effect on target?

# %%
# Graphical analysis:
data = pd.crosstab(d['ca'],d['target'])
data.plot(kind='bar',stacked=False)
plt.xticks(rotation=45)
plt.title('Different coloured flourosopy versus target')
plt.show()

# %%
# assumption :
In the above graph, 0 is healthy person and 1 is disease person in target.
ca ranges from 0 to 4 are the different coloured flourosopy.

# %%
d['ca'].value_counts()
# Out:
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: ca, dtype: int64

# %%
d['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
# Hypothesis:
H0 : Number of major vessel colored by flourosopy has no effect on target
Ha : Number of major vessel colored by flourosopy has effect on target

# %%
data = pd.crosstab(d['ca'],d['target'])
data
# Out:
# target    0    1
# ca
# 0       163  415
# 1       160   66
# 2       113   21
# 3        60    9
# 4         3   15

# %%
# both the input features are categorical attributes with more than two category. so proceeding with chi2_contingency

# %%
chi2_contingency(data)

# pvalue < 0.05. Null hypothesis is rejected.
# Out:
# (257.2929975952664,
#  1.747013451046176e-54,
#  4,
#  array([[281.38731707, 296.61268293],
#         [110.02341463, 115.97658537],
#         [ 65.23512195,  68.76487805],
#         [ 33.59121951,  35.40878049],
#         [  8.76292683,   9.23707317]]))

# %%
# posthoc analysis:
P0ch = 163 / (163+415)
P1ch = 160 / (160+66)
P2ch = 113 / (113+21)
P3ch = 60 / (60+9)
P4ch = 3 / (3+15)

P0cd = 415 / (163+415)
P1cd = 66 / (160+66)
P2cd = 21 / (113+21)
P3cd = 9 / (60+9)
P4cd = 15 / (3+15)

(P0ch,P1ch,P2ch,P3ch),(P0cd,P1cd,P2cd,P3cd)

# In the above posthoc analysis, 86.95 is the highest proportion percentage which is aquried by number of vessel with 4 colored healthy person.
#  13.04 is the lowest proportion percentage which is aquried by number of vessel with 4 colored disease person.
# Out:
# ((0.2820069204152249,
#   0.7079646017699115,
#   0.8432835820895522,
#   0.8695652173913043),
#  (0.7179930795847751,
#   0.2920353982300885,
#   0.15671641791044777,
#   0.13043478260869565))
